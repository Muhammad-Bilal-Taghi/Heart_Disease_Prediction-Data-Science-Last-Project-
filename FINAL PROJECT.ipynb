# %% [markdown]
# ## HEART DISEASE PREDICTION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys

# %%
data = pd.read_csv("heart.csv")
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
plt.figure(figsize=(20,12))
sns.countplot(x='trestbps',hue='target',data=data)
plt.savefig('')
plt.show()

# %%
data.plot()

plt.show()


plt.savefig(sys.stdout)
sys.stdout.flush()
# Out:
# �PNG
#
#  �0������U����,�9�����d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$I@���d`$]A=o�8IEND�B`�

# %%
sns.set(font_scale=2)
data.hist(figsize=(30,30))
plt.savefig("hist.png")
plt.show()

# %%
sns.countplot(x='fbs',data=data)
plt.show()

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
categorical_value=list(data.columns)
print(list(enumerate(categorical_value,1)))
# Out:
# [(1, 'age'), (2, 'sex'), (3, 'cp'), (4, 'trestbps'), (5, 'chol'), (6, 'fbs'), (7, 'restecg'), (8, 'thalach'), (9, 'exang'), (10, 'oldpeak'), (11, 'slope'), (12, 'ca'), (13, 'thal'), (14, 'target')]

# %%
print(list(data.columns))
# Out:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']

# %%
categorical_value = list(data.columns)
categorical_value.remove('exang')
categorical_value
# Out:
# ['age',
#  'sex',
#  'cp',
#  'trestbps',
#  'chol',
#  'fbs',
#  'restecg',
#  'thalach',
#  'oldpeak',
#  'slope',
#  'ca',
#  'thal',
#  'target']

# %%
plt.figure(figsize=(70,70))
for i, col in enumerate(categorical_value, 1):
    plt.subplot(4,4,i)
    sns.barplot(x=f"{col}",y='target',data=data)
    plt.ylabel("Possibility of having heart disease")
    plt.xlabel(f"{col}")

# %%
plt.figure(figsize=(20,12))
sns.countplot(x='age',hue='slope', data=data)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
# from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.naive_bayes import GaussianNB
# from sklearn.metrics import accuracy_score,confusion_matrix

# %% [markdown]
# ## Train test split

# %%
x = data.drop('slope', axis=1) 
y = data['slope']
print(y)
# arr = data.values
# x = arr[:,0:-1]
# y = arr[:,-1]

# testing_size = 0.2

# print(y)
# Out:
# 0       2
# 1       0
# 2       0
# 3       2
# 4       1
#        ..
# 1020    2
# 1021    1
# 1022    1
# 1023    2
# 1024    1
# Name: slope, Length: 1025, dtype: int64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = testing_size)

# %%
print(y_test)
# Out:
# 285    2
# 304    1
# 836    2
# 24     1
# 237    2
#       ..
# 861    2
# 663    1
# 17     1
# 699    2
# 94     2
# Name: slope, Length: 205, dtype: int64

# %%
modele = []
modele.append(('DT', DecisionTreeClassifier()))
modele.append(('RT', RandomForestClassifier()))
# modele.append(('sex', DecisionTreeClassifier()))
# modele.append(('chol', RandomForestClassifier()))
# modele.append(('fbs', DecisionTreeClassifier()))
# modele.append(('restecg', RandomForestClassifier()))
# modele.append(('thal', DecisionTreeClassifier()))
# modele.append(('exang', RandomForestClassifier()))
# modele.append(('oldpeak', DecisionTreeClassifier()))
# modele.append(('slope', RandomForestClassifier()))
# modele.append(('ca', DecisionTreeClassifier()))
# model.append(('chol', GaussianNB()))
# # model.append(('slope', LogisticRegression()))

# %%
print(modele)
# Out:
# [('DT', DecisionTreeClassifier()), ('RT', RandomForestClassifier())]

# %%
names = []
results = []

# %%
#  for name, models in modele:
#     obj = models
#     names.append(name)
#     obj.fit(x_train , y_train)
#     y_pred = obj.predict(x_test)
#     results.append(accuracy_score(y_test,y_pred)*100)
#     print(results)

for name, models in modele:
    obj = models
    names.append(name)
    obj.fit(x_train,y_train)
    y_pred = obj.predict(x_test)
    results.append(accuracy_score(y_test,y_pred)*100)
    print(results)
# Out:
# [98.53658536585365]
# [98.53658536585365, 97.07317073170731]

# %%
plt.scatter(names,results)

# %%
plt.plot(names,results)
